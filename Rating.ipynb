# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

# %%
# Read the Airbnb ratings data from the CSV file
airbnb_df = pd.read_csv("Ratings.csv")

# %%
# Replace commas and convert price column to float
airbnb_df['price'] = airbnb_df['price'].str.replace(',', '').astype(float)

# Group by rating and calculate the mean price for each rating
airbnb2 = airbnb_df.groupby('Rating')['price'].mean()

# %%
# Define a purple color palette with different shades
purple_palette = plt.cm.Purples(np.linspace(0.2, 1, len(airbnb2)))

# Plot the bar chart using the defined color palette
airbnb2.plot(kind="bar", color=purple_palette, legend=False, rot=50)

# Set title and labels with fancy fonts and colors
plt.title("Average Price by Rating", fontdict={'fontweight': 'bold', 'fontsize': 20, 'color': 'green', 'family': 'corbel'}, style='italic')
plt.xlabel("Rating", fontdict={'fontweight': 'bold', 'fontsize': 16, 'color': 'purple', 'family': 'corbel'}, style='italic')
plt.ylabel("Average Price", fontdict={'fontweight': 'bold', 'fontsize': 16, 'color': 'purple', 'family': 'corbel'}, style='italic')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# Save the plot as an image file
plt.savefig('barplot1.png', dpi=300)
